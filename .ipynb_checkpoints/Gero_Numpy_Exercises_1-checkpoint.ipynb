# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('TAULA_MAP_SCENSAL.csv')
data = df
# print(data)

# %%
data
# Out:
#       SECCIO_CENSAL  HOMES  DONES  EDAT_0_A_14  EDAT_15_A_24  EDAT_25_A_64  \
# 0              1001    663    608          156           106           816
# 1              1002    678    629          119           148           851
# 2              1003   1885   1597          721           446          1940
# 3              1004   1547   1314          347           314          1906
# 4              1005   1218   1061          279           271          1438
# ...             ...    ...    ...          ...           ...           ...
# 1063          10143    849    951          205           199          1004
# 1064          10234    807    974          159           156           941
# 1065          10235    615    681          134            95           689
# 1066          10236    740    846          143            96           813
# 1067          10237    406    508          105            97           505
#
# ...
